# %%
import cv2
import os
import matplotlib.pyplot as plt

def find_mean_variance(img):
    rows,cols=img.shape
    sum1=0
    for i in range(rows):
        for j in range(cols):
            sum1 += img[i,j]
    mean = sum1 / (rows * cols)

    varianceSum = 0
    for i in range(rows):
        for j in range(cols):
            varianceSum += (img[i,j] - mean) ** 2
    variance = varianceSum / (rows * cols)
    
    return mean,variance


image_dir='C:\\Users\\User\\ImageProcessing\\ImageProcessing\\image'
imglist=[]
for file in os.listdir(image_dir):
    if file.endswith(('.jpg','.jpeg','.png','.jiff')):
        file_path=os.path.join(image_dir,file)
        imglist.append(file_path)

means=[]
variances=[]

# plt.figure(figsize=(15,13))

for i in range(len(imglist)):
    print(imglist[i])
    imgob=cv2.imread(imglist[i])
    rgb=cv2.cvtColor(imgob,cv2.COLOR_BGR2RGB)
#     plt.subplot(5,5,i+1)
#     plt.imshow(rgb)
    
    gray_image = cv2.cvtColor(imgob, cv2.COLOR_BGR2GRAY) 
    mean, variance = find_mean_variance(gray_image)
    
    means.append(mean)
    variances.append(variance)

print("Means::",means)
print("Variance::",variance)
plt.scatter(means,variances)
# Out:
# C:\Users\User\ImageProcessing\ImageProcessing\image\Bekal.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\car.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\cat.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\cat1.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\dog.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\fish.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\flower1.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\fort.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\garden.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\house.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\icecream.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\kitten.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\laptop.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\lotus.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\nature.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\peacock.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\puppy.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\rose.jpeg
# C:\Users\User\ImageProcessing\ImageProcessing\image\royal.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\image\sunflower.jpg
# Means:: [113.6028275, 82.97833069198641, 151.08303571428573, 138.53715277777778, 98.73537837192647, 8.854235829300665, 92.20309651692709, 114.20970764160157, 93.50490710780056, 161.01280134421233, 174.58933262847623, 160.15482421875, 159.0929728190104, 50.71585919203747, 91.06930948832589, 113.45496568129566, 101.22029280462185, 58.855173703457446, 111.78223814630658, 113.46647760538642]
# Variance:: 4364.338952361926

# %%
#taking 10 rose image and 10 sunflower image
import cv2
import os
import matplotlib.pyplot as plt

def find_mean_variance(img):
    rows,cols=img.shape
    sum1=0
    for i in range(rows):
        for j in range(cols):
            sum1 += img[i,j]
    mean = sum1 / (rows * cols)

    varianceSum = 0
    for i in range(rows):
        for j in range(cols):
            varianceSum += (img[i,j] - mean) ** 2
    variance = varianceSum / (rows * cols)
    
    return mean,variance


image_dir='C:\\Users\\User\\ImageProcessing\\ImageProcessing\\Rose_sunflower'
imglist=[]
for file in os.listdir(image_dir):
    if file.endswith(('.jpg','.jpeg','.png','.jiff')):
        file_path=os.path.join(image_dir,file)
        imglist.append(file_path)

means=[]
variances=[]

# plt.figure(figsize=(15,13))

for i in range(len(imglist)):
    print(imglist[i])
    imgob=cv2.imread(imglist[i])
    if imgob is None:
        print(f"Error reading image {imglist[i]}")
        continue
    rgb=cv2.cvtColor(imgob,cv2.COLOR_BGR2RGB)
#     plt.subplot(5,5,i+1)
#     plt.imshow(rgb)
    
    gray_image = cv2.cvtColor(imgob, cv2.COLOR_BGR2GRAY) 
    mean, variance = find_mean_variance(gray_image)
    
    means.append(mean)
    variances.append(variance)

print("Means::",means)
print("Variance::",variance)
plt.scatter(means,variances)
plt.title("Mean Variance")
# Out:
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose1.jpg
# Error reading image C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose1.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose10.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose2.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose3.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose4.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose5.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose6.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose7.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose8.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\rose9.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower1.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower10.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower2.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower3.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower4.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower5.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower6.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower7.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower8.jpg
# C:\Users\User\ImageProcessing\ImageProcessing\Rose_sunflower\sunflower9.jpg
# Means:: [177.09618819444444, 93.6977446124634, 162.044048, 130.56382222222223, 33.31442356109619, 56.63576798349057, 80.56642906934312, 94.64033474789531, 101.62734284890426, 154.3892956542969, 157.41426532859077, 102.07899991184767, 86.0065640506817, 135.3269906323185, 187.97096592735454, 79.37622179073857, 155.056818, 137.37560213930627, 195.43854712041886]
# Variance:: 5188.278437035852
# Text(0.5, 1.0, 'Mean Variance')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load images
image1 = cv2.imread('cat1.jpg')
image2 = cv2.imread('dog.jpg')
rows, cols = image2.shape[:2]

# Ensure the images are of the same size
image1 = cv2.resize(image1, (cols,rows))

added_image = cv2.add(image1, image2)
sub_image = cv2.subtract(image2, image1)
multiplied_image = cv2.multiply(image1, image2)

image1_float = image1.astype(np.float32)
image2_float = image2.astype(np.float32) + 1  # Adding 1 to avoid division by zero

divided_image = cv2.divide(image1_float, image2_float)

# Convert back to uint8
divided_image = cv2.normalize(divided_image, None, 0, 255, cv2.NORM_MINMAX)
divided_image = divided_image.astype(np.uint8)

plt.figure(figsize = (13,18))
plt.subplot(3,2,1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(3,2,2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(3,2,3)
plt.imshow(cv2.cvtColor(added_image, cv2.COLOR_BGR2RGB))
plt.title('Added Image')

plt.subplot(3,2,4)
plt.imshow(cv2.cvtColor(sub_image, cv2.COLOR_BGR2RGB))
plt.title('Subtracted Image')

plt.subplot(3,2,5)
plt.imshow(cv2.cvtColor(multiplied_image, cv2.COLOR_BGR2RGB))
plt.title('Multiplied Image')

plt.subplot(3,2,6)
plt.imshow(cv2.cvtColor(divided_image, cv2.COLOR_BGR2RGB))
plt.title('Divided Image')
# Out:
# Text(0.5, 1.0, 'Divided Image')

# %%
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread('cat.jpg')
img2=cv2.imread('cat1.jpg')
row1,col1=img1.shape[:2]
img2=cv2.resize(img2,(col1,row1))
addimg=img1+img2
addimg=cv2.cvtColor(addimg,cv2.COLOR_BGR2RGB)
plt.imshow(addimg)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
#bitwise_operations
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load two images
img1 = cv2.imread('cat1.jpg')
img2 = cv2.imread('dog.jpg')

# Resize images to the same dimensions if needed
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Perform bitwise AND operation
bitwise_and = cv2.bitwise_and(img1, img2)

# Perform bitwise OR operation
bitwise_or = cv2.bitwise_or(img1, img2)

# Perform bitwise XOR operation
bitwise_xor = cv2.bitwise_xor(img1, img2)

# Perform bitwise NOT operation
bitwise_not_img1 = cv2.bitwise_not(img1)
bitwise_not_img2 = cv2.bitwise_not(img2)

# Display results
plt.figure(figsize = (10,15))
plt.subplot(4,2,1)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(4,2,2)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(4,2,3)
plt.imshow(cv2.cvtColor(bitwise_and, cv2.COLOR_BGR2RGB))
plt.title('Bitwise AND')

plt.subplot(4,2,4)
plt.imshow(cv2.cvtColor(bitwise_or, cv2.COLOR_BGR2RGB))
plt.title('Bitwise OR')

plt.subplot(4,2,5)
plt.imshow(cv2.cvtColor(bitwise_not_img1, cv2.COLOR_BGR2RGB))
plt.title('Bitwise NOT Image 1')

plt.subplot(4,2,6)
plt.imshow(cv2.cvtColor(bitwise_not_img2, cv2.COLOR_BGR2RGB))
plt.title('Bitwise NOT Image 2')

plt.subplot(4,2,7)
plt.imshow(cv2.cvtColor(bitwise_xor, cv2.COLOR_BGR2RGB))
plt.title('Bitwise XOR')
# Out:
# Text(0.5, 1.0, 'Bitwise XOR')

# %%
#logical_operation
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Function to threshold image to binary per channel
def threshold_image(image, threshold=128):
    # Split the image into its color channels
    channels = cv2.split(image)
    binary_channels = []
    for channel in channels:
        _, binary_channel = cv2.threshold(channel, threshold, 255, cv2.THRESH_BINARY)
        binary_channels.append(binary_channel)
    return cv2.merge(binary_channels)

# Load images
image1 = cv2.imread('cat1.jpg')
image2 = cv2.imread('dog.jpg')

# Ensure the images are of the same size
image1 = cv2.resize(image1, (image2.shape[1], image2.shape[0]))

# Threshold images to create binary images
binary_image1 = threshold_image(image1)
binary_image2 = threshold_image(image2)

# Perform logical AND operation
logical_and = np.logical_and(binary_image1, binary_image2).astype(np.uint8) * 255

# Perform logical OR operation
logical_or = np.logical_or(binary_image1, binary_image2).astype(np.uint8) * 255

# Perform logical NOT operation on the first image
logical_not = np.logical_not(binary_image1).astype(np.uint8) * 255

# Display the results
plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image 1')

plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image 2')

plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(logical_and, cv2.COLOR_BGR2RGB))
plt.title('Logical AND')

plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(logical_or, cv2.COLOR_BGR2RGB))
plt.title('Logical OR')

plt.figure()
plt.imshow(cv2.cvtColor(logical_not, cv2.COLOR_BGR2RGB))
plt.title('Logical NOT')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Function to add two images manually
def add_images(image1, image2):
    # Ensure the images have the same dimensions
    if image1.shape != image2.shape:
        raise ValueError("Images must have the same dimensions for addition.")
   
    # Convert images to int32 to handle overflow
    image1_int = image1.astype(np.int32)
    image2_int = image2.astype(np.int32)
   
    # Create an empty array for the output image
    result_image = np.zeros_like(image1_int)
   
    rows, cols, channels = image1_int.shape
   
    # Manually add pixel values
    for row in range(rows):
        for col in range(cols):
            for channel in range(channels):
                pixel_sum = image1_int[row, col, channel] + image2_int[row, col, channel]
                result_image[row, col, channel] = np.clip(pixel_sum, 0, 255)
   
    # Convert back to uint8
    result_image = result_image.astype(np.uint8)
   
    return result_image

# Load images
image1 = cv2.imread('dog.jpg')
image2 = cv2.imread('cat1.jpg')

# Ensure the images are of the same size
image1 = cv2.resize(image1, (image2.shape[1], image2.shape[0]))

# Add images manually
added_image = add_images(image1, image2)

# Display the result
plt.figure(figsize=(12, 8))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image 1')

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image 2')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(added_image, cv2.COLOR_BGR2RGB))
plt.title('Added Image')
# Out:
# Text(0.5, 1.0, 'Added Image')
