# %%
import cv2
import matplotlib.pyplot as plt
image_path = 'C:/Users/MANGAORE UNIVERSITY/Image_Processing/pic1.jpg'

original_image = cv2.imread(image_path)
plt.subplot(2, 3, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
plt.subplot(2, 3, 2)
plt.title(' Grayscale Image')
plt.imshow(gray_image , cmap='gray')

_,binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
plt.subplot(2,3,3)
plt.title('Binary image')
plt.imshow(binary_image,cmap='gray')

blue_channel, green_channel, red_channel = cv2.split(original_image)

plt.subplot(2,3,4)
plt.title('Red Channel')
plt.imshow(red_channel, cmap = 'Reds')

plt.subplot(2,3,5)
plt.title('Green Channel')
plt.imshow(green_channel, cmap='Greens')

plt.subplot(2,3,6)
plt.title('Blue Channel')
plt.imshow(blue_channel, cmap='Blues')

plt.show()

# %%
#other ,ashitha program
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('C:/Users/MANGAORE UNIVERSITY/Image_Processing/flower1.jpg')
plt.subplot(2,3,1)
plt.title("Original")
plt.imshow(image)

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.subplot(2,3,2)
plt.title("Grayscale")
plt.imshow(gray_image, cmap = 'gray')

_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
plt.subplot(2,3,3)
plt.title("Binary")
plt.imshow(binary_image, cmap = 'gray')

blue_channel, green_channel, red_channel = cv2.split(image)

plt.subplot(2,3,4)
plt.title('Red Channel')
plt.imshow(red_channel, cmap = 'Reds')

plt.subplot(2,3,5)
plt.title('Green Channel')
plt.imshow(green_channel, cmap='Greens')

plt.subplot(2,3,6)
plt.title('Blue Channel')
plt.imshow(blue_channel, cmap='Blues')

# %%
#display mean,standard deviation,correlation,coefficient
import cv2
import numpy as np
image = cv2.imread('C:/Users/MANGAORE UNIVERSITY/Image_Processing/flower1.jpg',cv2.IMREAD_GRAYSCALE)
mean_value = np.mean(image)
std_dev = np.std(image)
correlation_Coefficient = np.corrcoef(image)[0, 1]
print(f"Mean: {mean_value}")
print(f"Standard Deviation: {std_dev}")
print(f"Correlation Coefficient: {correlation_Coefficient}")
# Out:
# Mean: 200.845391
# Standard Deviation: 74.61436445522483
# Correlation Coefficient: 1.0

# %%
#display bit plane image
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('C:/Users/MANGAORE UNIVERSITY/Image_Processing/flower1.jpg', cv2.IMREAD_GRAYSCALE)

for i in range(8):
    # Extract the i-th bit plane
    bit_plane = (image >> i) & 1

    # Display the bit plane
    plt.subplot(2, 4, i+1)
    plt.imshow(bit_plane, cmap='gray')
    plt.title(f'Bit Plane {i}')
    plt.axis('off')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
#display image using median blur
import cv2 
import matplotlib.pyplot as plt 
import numpy as np 
image = cv2.imread('flower1.jpg') 
plt.subplot(1, 2, 1) 
plt.title("Original") 
plt.imshow(image) 
# Remove noise using a median filter 
filtered_image = cv2.medianBlur(image, 35) 
#Save the image 
cv2.imwrite('Median Blur.jpg', filtered_image) 
#Plot the blured image 
plt.subplot(1, 2, 2) 
plt.title("Median Blur") 
plt.imshow(filtered_image) 
plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np 
image = cv2.imread('ganesh.jpg') 
plt.subplot(1, 2, 1) 
plt.title("Original") 
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) 
# Remove noise using a median filter 
filtered_image = cv2.medianBlur(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), 35) 
#Save the image 
cv2.imwrite('Median Blur.jpg', filtered_image) 
#Plot the blured image 
plt.subplot(1, 2, 2) 
plt.title("Median Blur") 
plt.imshow(filtered_image) 
plt.show()

# %%
#resizing image
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image =cv2.imread('eye.jpg')

# Convert BGR image to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Define the scale factor
# Increase the size by 3 times
scale_factor_1 = 3.0  
# Decrease the size by 3 times
scale_factor_2 = 1/3.0

# Get the original image dimensions
height, width = image_rgb.shape[:2]

# Calculate the new image dimensions
new_height = int(height * scale_factor_1)
new_width = int(width * scale_factor_1)

# Resize the image
zoomed_image = cv2.resize(src =image_rgb, 
                          dsize=(new_width, new_height), 
                          interpolation=cv2.INTER_CUBIC)

# Calculate the new image dimensions
new_height1 = int(height * scale_factor_2)
new_width1 = int(width * scale_factor_2)

# Scaled image
scaled_image = cv2.resize(src= image_rgb, 
                          dsize =(new_width1, new_height1), 
                          interpolation=cv2.INTER_AREA)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(10, 4))

# Plot the original image
axs[0].imshow(image_rgb)
axs[0].set_title('Original Image Shape:'+str(image_rgb.shape))

# Plot the Zoomed Image
axs[1].imshow(zoomed_image)
axs[1].set_title('Zoomed Image Shape:'+str(zoomed_image.shape))

# Plot the Scaled Image
axs[2].imshow(scaled_image)
axs[2].set_title('Scaled Image Shape:'+str(scaled_image.shape))

# Remove ticks from the subplots
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

# Display the subplots
plt.tight_layout()
plt.show()

# %%
#image intensity slicing technique for image enhancement
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("flower1.jpg")

low_threshold = 100  
high_threshold = 200

# Apply intensity slicing
result_img = np.zeros_like(img)
result_img[(img >= low_threshold) & (img <= high_threshold)] = 255

# Plot the original and result images using Matplotlib
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Enhanced image
plt.subplot(1, 2, 2)
plt.imshow(result_img, cmap='gray')
plt.title('Enhanced Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#image intensity slicing technique for image enhancement
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("flower1.jpg",cv2.IMREAD_GRAYSCALE)

low_threshold = 100  
high_threshold = 200

# Apply intensity slicing
result_img = np.zeros_like(img)
result_img[(img >= low_threshold) & (img <= high_threshold)] = 255

# Plot the original and result images using Matplotlib
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Enhanced image
plt.subplot(1, 2, 2)
plt.imshow(result_img, cmap='gray')
plt.title('Enhanced Image')
plt.axis('off')

plt.tight_layout()
plt.show()
